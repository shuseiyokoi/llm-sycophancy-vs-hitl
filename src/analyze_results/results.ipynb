# %%
from analyze_results import analyze_results
analyze_results()
# Out:
# Gemini:
# conclusion   NO  YES
# prompt
# Control     234   66
# Emotional   300    0
# Chi-square p = 2.23e-17
# Fisher p     = 4.85e-22
#
# ChatGPT:
# conclusion   NO  YES
# prompt
# Control     296    4
# Emotional   299    1
# Chi-square p = 0.369
# Fisher p     = 0.373
# Analysis completed
